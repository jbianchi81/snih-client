# %%
import snih_client
import pandas
from datetime import datetime, timedelta

# %%
estaciones = snih_client.leerEstaciones()
df_estaciones = pandas.DataFrame(estaciones)
df_estaciones
# Out:
#                                    __type  Codigo  \
# 0     Compartido.Contenedor.CEstacionesCN  111872
# 1     Compartido.Contenedor.CEstacionesCN   10420
# 2     Compartido.Contenedor.CEstacionesCN  270905
# 3     Compartido.Contenedor.CEstacionesCN  273383
# 4     Compartido.Contenedor.CEstacionesCN  272459
# ...                                   ...     ...
# 1379  Compartido.Contenedor.CEstacionesCN   14001
# 1380  Compartido.Contenedor.CEstacionesCN   13266
# 1381  Compartido.Contenedor.CEstacionesCN   13248
# 1382  Compartido.Contenedor.CEstacionesCN   13339
# 1383  Compartido.Contenedor.CEstacionesCN   13050
#
#                             Descripcion  Regional  Sistema  Cuenca  Red  \
# 0            25 de Mayo - EEA Pergamino        -1        1      48   11
# 1                            7 de abril         1        5      85    1
# 2                        A denominar 10         0        3      22   27
# 3          A Determinar - Arroyo Amores         0        3      21   27
# 4     A Determinar - Campo La Invernada         0        3      22   27
# ...                                 ...       ...      ...     ...  ...
# 1379                             Zárate         3        1      37    1
# 1380                         ZONA RURAL         3        3      30    1
# 1381               Zona Rural Autopista         3        3      30    1
# 1382              Santa Fe - La Guardia        -1        3      27   99
# 1383                   Túnel Subfluvial        -1        3      17   99
#
#                   Subcuenca  Provincia                   Rio  ...  \
# 0                      None         13                  None  ...
# 1                    Urueña          3                Urueña  ...
# 2     Bajos Submeridionales          5                Salado  ...
# 3     Bajos Submeridionales         16          A Determinar  ...
# 4     Bajos Submeridionales         21          A Determinar  ...
# ...                     ...        ...                   ...  ...
# 1379   Paraná de las Palmas         13  Paraná de las Palmas  ...
# 1380               EL MONJE         16              EL MONJE  ...
# 1381              COLASTINÉ         16          A° Colastiné  ...
# 1382        Sistema Setúbal         -1       Sistema Setúbal  ...
# 1383                 Paraná         -1                Paraná  ...
#
#                        Departamento DistanciaDesembocadura  Habilitada  Tipo  \
# 0                              None                   None        True     M
# 1                              None                   None        True     H
# 2                            Moreno                   None        True     M
# 3                              Vera                   None        True    GA
# 4     Fray Justo Santa Maria de Oro                   None        True    GA
# ...                             ...                    ...         ...   ...
# 1379                           None                   None        True    HA
# 1380                           None                   None        True     H
# 1381                           None                   None        True     H
# 1382                           None                   None        True  None
# 1383                           None                   None        True  None
#
#       Transmision                                       ModoDeLlegar  Actual  \
# 0               T                             Estacion Forestal INTA       S
# 1               T                                               None       S
# 2               T  Saliendo desde la Ciudad de Santa Fe hacia el ...       S
# 3               M  Desde Corrientes, pasando por el Puente Genera...       S
# 4               M  Desde la localidad de Villa Angela dirigirse e...       S
# ...           ...                                                ...     ...
# 1379            T                                               None       S
# 1380            M                                               None       S
# 1381            M                                               None       S
# 1382            M                                               None       S
# 1383            M                                               None       S
#
#            RegistroValidoHasta  Autor                  Registro
# 0    2200-12-31 03:00:00+00:00      1 2019-12-12 18:26:42+00:00
# 1    2200-12-31 03:00:00+00:00    115 2021-09-30 18:49:56+00:00
# 2    2200-12-31 03:00:00+00:00    115 2024-01-04 15:10:33+00:00
# 3    2200-12-31 03:00:00+00:00    115 2023-12-21 19:13:07+00:00
# 4    2200-12-31 03:00:00+00:00    115 2023-12-21 19:13:08+00:00
# ...                        ...    ...                       ...
# 1379 2200-12-31 03:00:00+00:00      3 2021-08-02 20:45:55+00:00
# 1380 2200-12-31 03:00:00+00:00      3 2012-02-16 21:04:01+00:00
# 1381 2200-12-31 03:00:00+00:00    115 2020-05-24 04:55:11+00:00
# 1382 2200-12-31 03:00:00+00:00     -1 2200-12-31 03:00:00+00:00
# 1383 2200-12-31 03:00:00+00:00     -1 2200-12-31 03:00:00+00:00
#
# [1384 rows x 35 columns]

# %%
df_estaciones.plot(x="Longitud",y="Latitud", kind="scatter")
# Out:
# <AxesSubplot: xlabel='Longitud', ylabel='Latitud'>

# %%
codigos = snih_client.leerCodigosMedicion()
df_codigos = pandas.DataFrame(codigos)
df_codigos
# Out:
#                                __type  Tipo  Codigo  \
# 0    Compartido.Contenedor.CCodigosCN     4     339
# 1    Compartido.Contenedor.CCodigosCN     4     315
# 2    Compartido.Contenedor.CCodigosCN     4     314
# 3    Compartido.Contenedor.CCodigosCN     4     338
# 4    Compartido.Contenedor.CCodigosCN     4     340
# ..                                ...   ...     ...
# 174  Compartido.Contenedor.CCodigosCN     2     301
# 175  Compartido.Contenedor.CCodigosCN     4     282
# 176  Compartido.Contenedor.CCodigosCN     4     281
# 177  Compartido.Contenedor.CCodigosCN     4     358
# 178  Compartido.Contenedor.CCodigosCN    -1      -1
#
#                                            Descripcion Abreviatura   Unidad  \
# 0            2-metil-4-isotiazolin-3-ona (bactericida)          MI     ug/l
# 1                                   4,4 -DDE o p,p DDE    4,4 -DDE     µg/L
# 2                              4,4'-DDD(TDE) o p,p-DDD   4,4'- DDD     µg/L
# 3    5-cloro-2-metil-4-isotiazolin-3-ona (bactericida)         CMI     µg/L
# 4                                       Ácido Abiético  A.Abiético     ug/l
# ..                                                 ...         ...      ...
# 174                         Velocidad del viento media   Vel-v-med     km/h
# 175                                      Zinc disuelto    Zn (dis)     µg/l
# 176                                         Zinc total    Zn (tot)     µg/l
# 177            Zinc Total en sedimento/suelo seco (ss)   Zn Tot ss  µg/g ss
# 178                                              Aforo        None     None
#
#      Magnitud  Dato  Decimales  CodigoReferencia  DerechoMinimoRegistro  \
# 0           2     1          3                 0                    200
# 1           2     1          3                 0                    200
# 2           2     1          3                 0                    200
# 3           2     1          3                 0                    200
# 4           2     1          3                 0                    200
# ..        ...   ...        ...               ...                    ...
# 174         2     2          2                 0                    200
# 175         2     1          3                 0                    200
# 176         2     1          3                 0                    200
# 177         2     1          2                 0                    200
# 178        -1    -1         -1                -1                    200
#
#      AgrupacionesPosibles Actual       RegistroValidoHasta  Autor  \
# 0                       0      S 2200-12-31 03:00:00+00:00    115
# 1                       0      S 2200-12-31 03:00:00+00:00    115
# 2                       0      S 2200-12-31 03:00:00+00:00    115
# 3                       0      S 2200-12-31 03:00:00+00:00    115
# 4                       0      S 2200-12-31 03:00:00+00:00    115
# ..                    ...    ...                       ...    ...
# 174                     7      S 2200-12-31 03:00:00+00:00    115
# 175                     0      S 2200-12-31 03:00:00+00:00    115
# 176                     0      S 2200-12-31 03:00:00+00:00    115
# 177                     7      S 2200-12-31 03:00:00+00:00      3
# 178                    -1      S 2200-12-31 03:00:00+00:00     -1
#
#                      Registro
# 0   2019-11-14 21:40:41+00:00
# 1   2019-11-14 21:36:50+00:00
# 2   2019-11-14 21:36:43+00:00
# 3   2019-11-14 21:40:31+00:00
# 4   2019-11-14 21:40:47+00:00
# ..                        ...
# 174 2020-06-19 18:46:48+00:00
# 175 2019-11-14 21:30:50+00:00
# 176 2019-11-14 21:30:44+00:00
# 177 2021-08-02 20:25:36+00:00
# 178 2200-12-31 03:00:00+00:00
#
# [179 rows x 16 columns]

# %%
asociaciones = snih_client.leerListaAsociaciones()
df_asociaciones = pandas.DataFrame(asociaciones)
df_asociaciones
# Out:
#                                       __type  Estacion  Codigo  \
# 0      Compartido.Contenedor.CAsociacionesCN     60700      20
# 1      Compartido.Contenedor.CAsociacionesCN     60900      20
# 2      Compartido.Contenedor.CAsociacionesCN     60200      20
# 3      Compartido.Contenedor.CAsociacionesCN     61800      20
# 4      Compartido.Contenedor.CAsociacionesCN     60400      20
# ...                                      ...       ...     ...
# 12017  Compartido.Contenedor.CAsociacionesCN    282107      14
# 12018  Compartido.Contenedor.CAsociacionesCN    282107       5
# 12019  Compartido.Contenedor.CAsociacionesCN    280710     218
# 12020  Compartido.Contenedor.CAsociacionesCN    280710      14
# 12021  Compartido.Contenedor.CAsociacionesCN    280710       5
#
#                           Desde                      Hasta  Minimo  Maximo  \
# 0     1992-01-01 17:55:14+00:00  2200-12-31 03:00:00+00:00     0.0   190.0
# 1     1992-01-01 17:56:09+00:00  2200-12-31 03:00:00+00:00     0.0   190.0
# 2     1992-01-01 17:58:14+00:00  2200-12-31 03:00:00+00:00     0.0   190.0
# 3     1992-01-01 17:59:08+00:00  2200-12-31 03:00:00+00:00     0.0   190.0
# 4     1992-01-01 18:00:05+00:00  2200-12-31 03:00:00+00:00     0.0   190.0
# ...                         ...                        ...     ...     ...
# 12017 2000-01-01 03:00:00+00:00  2200-12-31 03:00:00+00:00  -998.0  9999.0
# 12018 2000-01-01 03:00:00+00:00  2200-12-31 03:00:00+00:00  -998.0  9999.0
# 12019 2000-01-01 03:00:00+00:00  2200-12-31 03:00:00+00:00  -998.0  9999.0
# 12020 2000-01-01 03:00:00+00:00  2200-12-31 03:00:00+00:00  -998.0  9999.0
# 12021 2000-01-01 03:00:00+00:00  2200-12-31 03:00:00+00:00  -998.0  9999.0
#
#        TipoValidacion Actual       RegistroValidoHasta  Autor  \
# 0                   3      S 2200-12-31 03:00:00+00:00     23
# 1                   3      S 2200-12-31 03:00:00+00:00     23
# 2                   3      S 2200-12-31 03:00:00+00:00     23
# 3                   3      S 2200-12-31 03:00:00+00:00     23
# 4                   3      S 2200-12-31 03:00:00+00:00     23
# ...               ...    ...                       ...    ...
# 12017               1      S 2200-12-31 03:00:00+00:00    151
# 12018               1      S 2200-12-31 03:00:00+00:00    151
# 12019               1      S 2200-12-31 03:00:00+00:00    151
# 12020               1      S 2200-12-31 03:00:00+00:00    151
# 12021               1      S 2200-12-31 03:00:00+00:00    151
#
#                        Registro
# 0     2011-04-25 17:56:03+00:00
# 1     2011-04-25 17:56:57+00:00
# 2     2011-04-25 17:59:00+00:00
# 3     2011-04-25 17:59:56+00:00
# 4     2011-04-25 18:00:53+00:00
# ...                         ...
# 12017 2025-07-29 20:22:07+00:00
# 12018 2025-07-29 20:22:07+00:00
# 12019 2025-07-28 05:03:39+00:00
# 12020 2025-07-28 05:03:39+00:00
# 12021 2025-07-28 05:03:39+00:00
#
# [12022 rows x 12 columns]

# %%
datos_actuales = snih_client.leerDatosActuales(estacion=14081)
df_datos_actuales = pandas.DataFrame(datos_actuales)
df_datos_actuales
# Out:
#    ExtensionData  Codigo                 FechaHora  \
# 0             {}      30 2025-07-31 13:00:00+00:00
# 1             {}       4 2025-07-31 13:00:00+00:00
# 2             {}      18 2025-07-31 13:00:00+00:00
# 3             {}      20 2025-07-31 13:00:00+00:00
# 4             {}    9998 2025-07-31 13:00:00+00:00
# 5             {}     218 2025-07-31 13:00:00+00:00
# 6             {}      12 2025-07-31 13:00:00+00:00
# 7             {}      14 2025-07-31 13:00:00+00:00
# 8             {}       5 2025-07-31 13:00:00+00:00
# 9             {}      31 2025-07-31 13:00:00+00:00
# 10            {}      32 2025-07-31 13:00:00+00:00
# 11            {}      33 2025-07-31 13:00:00+00:00
# 12            {}      34 2025-07-31 13:00:00+00:00
#
#                                NombreCodigo     Valor
# 0                Profundidad Nivel Freático     5.060
# 1                      Velocidad del Viento     7.000
# 2                                   Humedad    78.000
# 3                             Precipitación     0.000
# 4                 Precipitación Instantánea     0.000
# 5                Presión Atmosférica [mBar]  1011.200
# 6                           Radiacion Solar   235.000
# 7                    Temperatura Bulbo Seco    15.500
# 8                      Dirección del Viento   352.000
# 9                     Temperatura del Suelo    12.800
# 10                 Permitividad Dieléctrica    26.580
# 11                        Humedad del Suelo     0.385
# 12  Conductividad Eléctrica de Poro de Agua     0.140

# %%
ultimos_registros = snih_client.leerUltimosRegistros(14081, 30, datetime.now() - timedelta(days=30), datetime.now())
df_ultimos_registros = pandas.DataFrame(ultimos_registros)
df_ultimos_registros
# Out:
#     ExtensionData                 FechaHora  Codigo  Valor
# 0              {} 2025-07-01 03:00:00+00:00      30   4.89
# 1              {} 2025-07-01 04:00:00+00:00      30   4.89
# 2              {} 2025-07-01 05:00:00+00:00      30   4.89
# 3              {} 2025-07-01 06:00:00+00:00      30   4.90
# 4              {} 2025-07-01 12:00:00+00:00      30   4.90
# ..            ...                       ...     ...    ...
# 645            {} 2025-07-31 09:00:00+00:00      30   5.06
# 646            {} 2025-07-31 10:00:00+00:00      30   5.06
# 647            {} 2025-07-31 11:00:00+00:00      30   5.06
# 648            {} 2025-07-31 12:00:00+00:00      30   5.06
# 649            {} 2025-07-31 13:00:00+00:00      30   5.06
#
# [650 rows x 4 columns]

# %%
df_ultimos_registros.plot(x="FechaHora",y="Valor")
# Out:
# <AxesSubplot: xlabel='FechaHora'>

# %%
historicos = snih_client.leerDatosHistoricos(66163, 1, datetime(2022,12,1), datetime(2023,1,1))
df_historicos = pandas.DataFrame(historicos)
df_historicos
# Out:
#                     FechaHora  Medicion Calificador  Validado
# 0   2022-12-23 13:45:00+00:00      1.12                  True
# 1   2022-12-23 14:45:00+00:00      1.04                  True
# 2   2022-12-23 15:45:00+00:00      0.98                  True
# 3   2022-12-23 16:45:00+00:00      0.92                  True
# 4   2022-12-23 17:45:00+00:00      0.86                  True
# ..                        ...       ...         ...       ...
# 201 2022-12-31 22:45:00+00:00      2.07                  True
# 202 2022-12-31 23:45:00+00:00      1.98                  True
# 203 2023-01-01 00:45:00+00:00      1.93                  True
# 204 2023-01-01 01:45:00+00:00      1.94                  True
# 205 2023-01-01 02:45:00+00:00      2.14                  True
#
# [206 rows x 4 columns]

# %%
df_historicos.plot(x="FechaHora",y="Medicion")
# Out:
# <AxesSubplot: xlabel='FechaHora'>
